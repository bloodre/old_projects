# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\USER\Desktop\prog/Python/ogoxi\Loire-Cher-Indre\Loire-Cher-Indre\Loire Forezienne\merged.csv", sep=";",parse_dates=["Date"],index_col="Date")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d483f4cb337b> in <module>
# ----> 1 import pandas as pd
#       2 df = pd.read_csv(r"C:\Users\USER\Desktop\prog/Python/ogoxi\Loire-Cher-Indre\Loire-Cher-Indre\Loire Forezienne\merged.csv", sep=";",parse_dates=["Date"],index_col="Date")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.head()
# Out:
#                      K0567520  K0614010  K0744010  K0643110  K0663310  \
# Date
# 2009-12-30 00:00:00       NaN       NaN       NaN       NaN      38.0
# 2009-12-30 00:12:00       NaN       NaN       NaN       NaN      37.9
# 2009-12-30 00:15:00      50.3       NaN       NaN       NaN       NaN
# 2009-12-30 00:20:00       NaN       NaN       NaN       NaN       NaN
# 2009-12-30 00:25:00       NaN       NaN       NaN       NaN       NaN
#
#                      K0673310  K0700010  H (cm)  K0624510  K0753210  K0773220  \
# Date
# 2009-12-30 00:00:00       NaN    -107.2     NaN       NaN       NaN       NaN
# 2009-12-30 00:12:00       NaN       NaN     NaN       NaN       NaN       NaN
# 2009-12-30 00:15:00       NaN       NaN     NaN       NaN       NaN       NaN
# 2009-12-30 00:20:00       NaN    -107.4     NaN       NaN       NaN       NaN
# 2009-12-30 00:25:00       NaN       NaN     NaN       NaN       NaN       NaN
#
#                      K0813020
# Date
# ...

# %%
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (20,10)
df_hours_mean = df.resample('60T').mean()
df_interpolate = df_hours_mean.interpolate(method="time")
df_interpolate = df_interpolate.dropna()
df_interpolate
#df['2015-01-01':'2016-01-01'].plot()
#df_hours_mean
# Out:
#                       K0567520   K0614010   K0744010   K0643110   K0663310  \
# Date
# 2015-12-01 11:00:00  62.350000  34.100000  20.758824  12.500000  33.303333
# 2015-12-01 12:00:00  62.800000  34.350000  20.682353  12.496296  33.266667
# 2015-12-01 13:00:00  62.250000  34.600000  20.605882  12.492593  33.230000
# 2015-12-01 14:00:00  62.700000  35.200000  20.529412  12.488889  33.193333
# 2015-12-01 15:00:00  62.533333  34.300000  20.452941  12.485185  33.156667
# 2015-12-01 16:00:00  62.366667  34.400000  20.376471  12.481481  33.120000
# 2015-12-01 17:00:00  62.483333  34.500000  20.300000  12.477778  33.083333
# 2015-12-01 18:00:00  62.600000  34.050000  20.350000  12.474074  33.046667
# 2015-12-01 19:00:00  62.900000  33.600000  20.400000  12.470370  33.010000
# 2015-12-01 20:00:00  63.200000  33.800000  20.520000  12.466667  32.973333
# 2015-12-01 21:00:00  63.300000  34.600000  20.640000  12.462963  32.936667
# ...

# %%
len(df_interpolate.index)
# Out:
# 24373
